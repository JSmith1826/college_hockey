# %% [markdown]
# # Scraper for Past Seasons from CHN
#
# ## For use on seasons 2021 and before that don't have advanced metrics

# %%
# Dependencies
## Dependencies
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import logging
from tqdm import tqdm
import re
from sqlalchemy import create_engine
import sqlite3


### SET TARGET YEAR
season_year = 2020

# Tags and Paths
FILE_TAG = f'Box_Scores{season_year}'

## global variables
current_year_url = f'https://www.collegehockeynews.com/schedules/?season={season_year}{season_year+1}'

tag = FILE_TAG
db_name = FILE_TAG
result_table_name = season_year


## Base usl for box scores and metrics

base_url = 'https://www.collegehockeynews.com'

# %% [markdown]
# ### Download a table of every game in CHN database for the selected season

# %%
## Functions
### Parse the current season schedule / results page

def parse_current_season(url):
        # Initialize variables
    current_date = None
    current_conference = None
    game_notes = None

    # Initialize an empty list to hold the data
    data = []

    # Parse the page with BeautifulSoup
    # Get the page with requests
    response = requests.get(url)

    # Create a BeautifulSoup object
    soup = BeautifulSoup(response.text, 'html.parser')

    # select the table or tables
    tables = soup.find_all('table')

    rows = soup.find_all('tr')

    # Loop through each row to find relevant information
    for row in rows:
        # Check for date row
        if row.get('class') == ['stats-section']:
            current_date = row.find('td').text.strip()
        # Check for conference row
        elif row.get('class') == ['sked-header']:
            current_conference = row.find('td').text.strip()
        # Check for game notes
        elif len(row.find_all('td')) == 2:
            game_notes = row.find_all('td')[1].text.strip()
        # Process rows with game data
        elif row.get('valign') == 'top':
            cells = row.find_all('td')
            if len(cells) >= 9:
                home_team = cells[0].text.strip()
                # Remove any hyphens from the team name
                home_team = home_team.replace('-', ' ')
                home_team_link = cells[0].find('a')['href'] if cells[0].find('a') else None
                home_score = cells[1].text.strip()
                away_team = cells[3].text.strip()
                away_team_link = cells[3].find('a')['href'] if cells[3].find('a') else None
                away_score = cells[4].text.strip()
                ot = cells[5].text.strip()
                box_link = cells[7].find('a')['href'] if cells[7].find('a') else None
                metrics_link = cells[8].find('a')['href'] if cells[8].find('a') else None
                # Capture Game Notes
                game_notes_cell = cells[-1].find('small')
                game_notes = game_notes_cell.text.strip() if game_notes_cell else None

                # Append data to the list
                data.append([current_date, current_conference, game_notes, home_team, home_team_link, home_score, away_team, away_team_link, away_score, ot, box_link, metrics_link])
                game_notes = None  # Reset game notes for the next row
    return data

## call the function
data = parse_current_season(current_year_url)


# Create a dataframe from the list

columns = ['Date', 'Conference', 'Game_Notes', 'Home_Team', 'Home_Team_Link', 'Home_Score', 'Away_Team', 'Away_Team_Link', 'Away_Score', 'OT', 'Box_Link', 'Metrics_Link']
df = pd.DataFrame(data, columns=columns)
            
## Extract the day of the week from the date and save in new column
df['Day'] = pd.to_datetime(df['Date']).dt.day_name()
# remove day of the week from date
# format data column as YYYY-MM-DD
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%Y-%m-%d')

### Create a new column for the game ID
## Game ID will be a combination of the date and abbreviated team names

# Function to abbreviate the team names
for row in df.itertuples():
    home_team = row.Home_Team
    away_team = row.Away_Team
    home_team_abbr = home_team.split(' ')[-1]
    away_team_abbr = away_team.split(' ')[-1]
    # Remove any hyphens from the team name if there are any
    home_team_abbr = home_team_abbr.replace('-', ' ')
    away_team_abbr = away_team_abbr.replace('-', ' ')
    game_id = f'{row.Date}-{home_team_abbr}-{away_team_abbr}'
    df.loc[row.Index, 'Game_ID'] = game_id

# Create a new column for the game ID
df['Game_ID'] = df['Game_ID'].str.replace(',', '')

# Remove any hyphens from the team names if any
df['Home_Team'] = df['Home_Team'].str.replace('-', ' ')
df['Away_Team'] = df['Away_Team'].str.replace('-', ' ')

# Apply the function to the DataFrame
df['Game_ID'] = df.apply(lambda row: f'{row.Date}-{row.Home_Team}-{row.Away_Team}', axis=1)

## Filter out games that have not been played yet
df = df[df['Home_Score'] != '']

# Replace Nan values in metrics column with empty string
df['Metrics_Link'] = df['Metrics_Link'].fillna('')

# save the dataframe to a csv file for manual review
df.to_csv('../TEMP/season_table_test.csv')

# Save copy of df before filter
df_pre = df.copy()

# Filter out Exhibition games
df = df[~df['Conference'].str.contains('Exhibition')]


# Print length of DF before and after filter
print(len(data))
print(len(df_pre))
print(len(df))
# Out:
# 601
# 601
# 599

# %% [markdown]
# # Sub Functions

# %%
## Functions for parsing the box score and metrics pages

# Initialize logging for Error and Warning messages
logging.basicConfig(filename='../TEMP/PAST_scrape.log', level=logging.INFO)

#### PARSE PLAYER STATS TABLE ####
def parse_player_summary(html_content):
    # Initialize BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find the playersums div
    playersums_div = soup.find('div', id='playersums')
    if playersums_div is None:
        return "Player summaries div not found"

    # Initialize list to store player stats
    player_stats = []

    # Loop through each playersum div
    for player_sum in playersums_div.find_all('div', class_='playersum'):
        team = player_sum.find('td').text.strip()
        
        # Loop through table rows
        for row in player_sum.find_all('tr'):
            cols = row.find_all('td')
            if len(cols) > 1:
                player = cols[0].text.strip()
                goals = cols[1].text.strip()
                assists = cols[2].text.strip()
                points = cols[3].text.strip()
                plus_minus = cols[4].text.strip()
                shots = cols[5].text.strip()
                pim = cols[6].text.strip()
                fowl = cols[7].text.strip() if len(cols) > 7 else None
                
                fow, fol = None, None
                win_percentage = None
                
                

                try:
                    if fowl and '‑' in fowl:  # Checking if it contains a hyphen
                        fow, fol = map(int, fowl.split('‑'))
                        total_fo = fow + fol
                        win_percentage = (fow / total_fo) * 100 if total_fo > 0 else 0
                except ValueError:
                    fow, fol, win_percentage = None, None, None

                

                
                player_stat = {
                    'Team': team,
                    'Player': player,
                    'G': goals,
                    'A': assists,
                    'Pt.': points,
                    '+/-': plus_minus,
                    'Sh': shots,
                    'PIM': pim,
                    'FOW': fow,
                    'FOL': fol,
                    'FO%': win_percentage
                }
                player_stats.append(player_stat)

    return pd.DataFrame(player_stats)


############# PARSEING SCORING SUMMARY WITH BS4

def parse_scoring_summary(html_content):
    # Initialize BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the scoring div and table
    scoring_div = soup.find('div', id='scoring')
    if scoring_div is None:
        logging.error("Scoring div not found")
        return None

    scoring_table = scoring_div.find('table')
    if scoring_table is None:
        logging.error("Scoring table not found within the scoring div")
        return None

    # Initialize list to store scoring events
    scoring_events = []
    period = None

    # Loop through table rows
    for row in scoring_table.find_all('tr'):
        if 'stats-section' in row.get('class', []):
            td = row.find('td')
            if td:
                period = td.text.strip()
            else:
                logging.warning("Period name not found in 'stats-section' row")
                period = "Unknown"
        else:
            cols = row.find_all('td')
            if len(cols) > 1:
                try:
                    team = cols[0].text.strip()
                    pp = cols[1].text.strip()

                    player_data = cols[3].text.strip()
                    match = re.match(r"(.+)\s\((\d+)\)", player_data)
                    player = match.group(1) if match else player_data
                    goals = int(match.group(2)) if match else None

                    assist_data_raw = cols[4].text.strip()
                    assist_data = assist_data_raw.split(", ") if assist_data_raw else []
                    assist1 = assist_data[0] if len(assist_data) > 0 else None
                    assist2 = assist_data[1] if len(assist_data) > 1 else None

                    time = cols[5].text.strip()

                    scoring_event = {
                        'Period': period,
                        'Team': team,
                        'PP': pp,
                        'Player': player,
                        'Player_Goals': goals,
                        'Assist1': assist1,
                        'Assist2': assist2,
                        'Time': time
                    }
                    scoring_events.append(scoring_event)
                except Exception as e:
                    logging.error(f"An error occurred while parsing a scoring event row: {e}")
            else:
                logging.warning(f"Insufficient columns in scoring row: {len(cols)}")

    return pd.DataFrame(scoring_events)


############# PARSEING PENALTY SUMMARY WITH BS4

def parse_penalty_summary(html_content):
    # Initialize BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the penalties div and table
    penalties_div = soup.find('div', id='penalties')
    if penalties_div is None:
        logging.error("Penalties div not found")
        return None

    penalties_table = penalties_div.find('table')
    if penalties_table is None:
        logging.error("Penalties table not found within the penalties div")
        return None

    # Initialize list to store penalty events
    penalty_events = []
    period = None

    # Loop through table rows
    for row in penalties_table.find_all('tr'):
        if 'stats-section' in row.get('class', []):
            td = row.find('td')
            if td:
                period = td.text.strip()
            else:
                logging.warning("Period name not found in 'stats-section' row")
                period = "Unknown"
        else:
            cols = row.find_all('td')
            if len(cols) > 1:
                team = cols[0].text.strip()
                player = cols[1].text.strip()
                pen_length = cols[2].text.strip()
                penalty_type = cols[3].text.strip()
                time = cols[4].text.strip()

                penalty_event = {
                    'Period': period,
                    'Team': team,
                    'Player': player,
                    'Pen_Length': pen_length,
                    'Penalty_Type': penalty_type,
                    'Time': time
                }
                penalty_events.append(penalty_event)

    return pd.DataFrame(penalty_events)


############# GOALIE SUMMARY WITH BS4
def parse_goalie_stats(html_content):
    # Initialize BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the goalies div and table
    goalies_div = soup.find('div', id='goalies')
    if goalies_div is None:
        logging.error("Goalies div not found")
        return None

    goalies_table = goalies_div.find('table')
    if goalies_table is None:
        logging.error("Goalies table not found within the goalies div")
        return None

    # Initialize list to store goalie stats
    goalie_stats = []
    team = None

    # Loop through table rows
    for row in goalies_table.find_all('tr'):
        if 'stats-header' in row.get('class', []):
            td = row.find('td')
            if td:
                team = td.text.strip()
            else:
                logging.warning("Team name not found in 'stats-header' row")
                team = "Unknown"
        else:
            cols = row.find_all('td')
            if len(cols) > 1:
                goalie = cols[0].text.strip()
                sv = cols[1].text.strip()
                ga = cols[2].text.strip()
                minutes = cols[3].text.strip()

                goalie_stat = {
                    'Team': team,
                    'Goalie': goalie,
                    'SV': sv,
                    'GA': ga,
                    'Minutes': minutes
                }
                goalie_stats.append(goalie_stat)

    return pd.DataFrame(goalie_stats)



### Get the Linescore Elements - Score, shots, ect by period####
#DONE - I THINK ### NEEDS UPDATE NOW THAT POSTSEASON MEAND 5th, 6th, ect PERIODS

def parse_linescore(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    linescore_data = []
    
    # Parsing the Goals table
    goals_table = soup.select_one("#goals table")
    if goals_table is None:
        logging.error("Goals table not found")
        return None
    
    rows = goals_table.select('tbody tr')
    if not rows:
        logging.warning("No rows found in Goals table")
        return None
    
    for row in rows:
        team_data = {}
        td = row.select_one('td')
        if td:
            team_data['Team'] = td.text
        else:
            logging.warning("Team name not found in Goals table")
            continue

        goals = row.select('td')[1:]
        for i, goal in enumerate(goals):
            period = i + 1
            column_name = f'goals{period}' if i < len(goals) - 1 else 'goalsT'
            team_data[column_name] = int(goal.text)
        
        linescore_data.append(team_data)
    

    # Parsing the Shots table
    shots_table = soup.select_one("#shots table")
    if shots_table is None:
        logging.error("Shots table not found")
        return None

    rows = shots_table.select('tbody tr')
    if not rows:
        logging.warning("No rows found in Shots table")
        return None

    for i, row in enumerate(rows):
        shots = row.select('td')[1:]
        if not shots:
            logging.warning(f"No shot data found for row {i+1} in Shots table")
            continue

        for j, shot in enumerate(shots):
            period = j + 1
            column_name = f'shots{period}' if j < len(shots) - 1 else 'shotsT'
            try:
                linescore_data[i][column_name] = int(shot.text.strip())
            except ValueError:
                logging.warning(f"Could not convert shot data to integer for row {i+1}, column {j+1}")
                linescore_data[i][column_name] = None

    # Parsing the PP table
    pp_table = soup.select_one("#pp table")
    if pp_table is None:
        logging.error("PP table not found")
        return None

    rows = pp_table.select('tbody tr')
    if not rows:
        logging.warning("No rows found in PP table")
        return None

    for i, row in enumerate(rows):
        try:
            pen_pim = row.select('td')[1].text.split('‑')
            linescore_data[i]['Pen'] = int(pen_pim[0])
            linescore_data[i]['PIM'] = int(pen_pim[1])

            ppg_ppo = row.select('td')[2].text.split('‑')
            linescore_data[i]['PPG'] = int(ppg_ppo[0])
            linescore_data[i]['PPO'] = int(ppg_ppo[1])

            fow_fol = row.select('td')[3].text.split('‑')
            linescore_data[i]['FOW'] = int(fow_fol[0])
            linescore_data[i]['FOL'] = int(fow_fol[1])
            linescore_data[i]['FOW%'] = (linescore_data[i]['FOW'] / (linescore_data[i]['FOW'] + linescore_data[i]['FOL'])) * 100

        except (ValueError, IndexError) as e:
            logging.warning(f"Could not process PP data for row {i+1}. Error: {e}")
            continue

    # Convert to DataFrame early
    df = pd.DataFrame(linescore_data)

    # Ensure all columns exist
    expected_goals_columns = [f'goals{i}' for i in range(1, 7)] + ['goalsT']
    expected_shots_columns = [f'shots{i}' for i in range(1, 7)] + ['shotsT']

    for col in expected_goals_columns + expected_shots_columns:
        if col not in df.columns:
            df[col] = 0

    # Return the final DataFrame
    return df



# Function to parse game details
def parse_game_details(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    meta_div = soup.find('div', {'id': 'meta'})
    if meta_div is None:
        logging.error("Meta div not found")
        return None
    
    game_details_div = meta_div.find_all('div')[-1]
    if game_details_div is None:
        logging.error("Game details div not found")
        return None
    
    try:
        date_str = game_details_div.h4.string
        day_of_week, date = date_str.split(", ", 1)
        
        p_elements = game_details_div.find_all('p')
        
        # Extract conference and location details
        for p in p_elements:
            if "Game" in p.text:  # e.g., "Big Ten Game"
                details_strs = p.get_text(separator='|').split('|')
                conference = details_strs[0]
                location = details_strs[-1].split('at ')[-1]
                break
        else:  # Defaults if not found
            conference, location = None, None
        
        # Extract referees and assistant referees details
        for p in p_elements:
            if "Referees" in p.text:
                refs_str = p.strong.next_sibling if p.strong else None
                asst_refs_str = p.find_all('strong')[1].next_sibling if len(p.find_all('strong')) > 1 else None
                break
        else:  # Defaults if not found
            refs_str, asst_refs_str = None, None
        
        refs = refs_str.split(', ') if refs_str else []
        asst_refs = asst_refs_str.split(', ') if asst_refs_str else []
        refs = [re.sub(r'[^a-zA-Z ]+', '', ref).strip() for ref in refs]
        asst_refs = [re.sub(r'[^a-zA-Z ]+', '', ref).strip() for ref in asst_refs]
        
        # Extract attendance details using regex for better accuracy
        attendance_pattern = r"Attendance:\s?(\d+[\d,]*)"
        attendance_match = re.search(attendance_pattern, html_content)
        attendance = int(attendance_match.group(1).replace(',', '')) if attendance_match else None
        
        # Extract game details (like shootout results)
        details = None
        for p in p_elements:
            if "shootout" in p.text:
                details = p.text
                break
        
        # Clean details if present
        if details and '\n' in details:
            details = details.replace('\n', '').strip()
        if details and '\t' in details:
            details = re.sub('\t', ' ', details)
        
        game_details = {
            'Day': day_of_week,
            'Date': date,
            'Conference': conference,
            'Details': details,
            'Location': location,
            'Ref1': refs[0] if refs else None,
            'Ref2': refs[1] if len(refs) > 1 else None,
            'Asst_Ref1': asst_refs[0] if asst_refs else None,
            'Asst_Ref2': asst_refs[1] if len(asst_refs) > 1 else None,
            'Attendance': attendance
        }
        
        game_details_df = pd.DataFrame([game_details])
        return game_details_df

    except (AttributeError, IndexError, ValueError) as e:
        logging.error(f"Error while parsing game details: {e}")
        return None


# PARENT FUNCTION TO PARSE BOX SCORE HTML
def parse_box_score(box_score_html):
    # Initialize DataFrames to None
    scoring_summary = penalty_summary = goalie_stats = player_stats = linescore = game_details = None
    
    try:
        scoring_summary = parse_scoring_summary(box_score_html)
    except Exception as e:
        print(f"Error in parse_scoring_summary: {e}")
    
    try:
        penalty_summary = parse_penalty_summary(box_score_html)
    except Exception as e:
        print(f"Error in parse_penalty_summary: {e}")
    
    try:
        goalie_stats = parse_goalie_stats(box_score_html)
    except Exception as e:
        print(f"Error in parse_goalie_stats: {e}")
    
    try:
        player_stats = parse_player_summary(box_score_html)
    except Exception as e:
        print(f"Error in parse_player_summary: {e}")
    
    try:
        game_details = parse_game_details(box_score_html)
    except Exception as e:
        print(f"Error in parse_game_details: {e}")

    try: 
        linescore = parse_linescore(box_score_html)
    except Exception as e:
        print(f"Error in parse_linescore: {e}")
    
    # Combine DataFrames into a list
    all_dfs = [game_details, scoring_summary, penalty_summary, goalie_stats, player_stats, linescore]
    
    return all_dfs


def rename_duplicate_columns(df):
    cols = pd.Series(df.columns)
    for dup in df.columns[df.columns.duplicated()].unique(): 
        cols[df.columns.get_loc(dup)] = [f"{dup}_{i}" if i != 0 else dup for i in range(df.columns.get_loc(dup).sum())]
    df.columns = cols
    return df

# %%
# Define table names for these DataFrames
table_names = ['game_details', 'scoring_summary', 'penalty_summary', 
                'goalie_stats', 'player_stats', 'linescore']

# # Filter data frame to just the first 10 games for testing
# df = df.head(5)

# %%
## Loop through each row of the DataFrame and parse the box score store the results in a dictionarey
box_score_data = {}

import tqdm

# Loop through each row of the DataFrame and parse the box score
for row in tqdm(df.itertuples()):
    # Get the box score link
    box_score_link = row.Box_Link
    
    game_id = row.Game_ID
    # print(f"Processing box score for {game_id}")
    # Get the box score page with requests
    box_score_response = requests.get(base_url + box_score_link)
    box_score_html = box_score_response.text
    # Parse the box score
    all_dfs = parse_box_score(box_score_html)
    # Store the DataFrames in the dictionary
    box_score_data[game_id] = dict(zip(table_names, all_dfs))
    # Sleep for 1 second to avoid overloading the server
    # time.sleep(1)

# Convert the dictionary to a set of dataframes with the game ID added to each DataFrame and the
# DataFrames renamed to match the table names
    
for game_id, dfs in box_score_data.items():
    for table_name, df in dfs.items():
        if df is not None:
            # Add the game ID to the DataFrame
            df['Game_ID'] = game_id
            # Rename duplicate columns
            df = rename_duplicate_columns(df)
            # Rename the DataFrame to match the table name
            box_score_data[game_id][table_name] = df

# Save the DataFrames to a SQLite database
            
# Set file path and name
db_path = f'../TEMP/{FILE_TAG}.db'            
# Create a connection to the database
conn = sqlite3.connect(db_path)

# Loop through the DataFrames and save them to the database
for game_id, dfs in box_score_data.items():
    for table_name, df in dfs.items():
        if df is not None:
            df.to_sql(table_name, conn, index=False, if_exists='append')

# Close the connection
conn.close()
# Out:
# Processing box score for 2020-11-13-Wisconsin-Notre Dame
# Processing box score for 2020-11-13-Adrian-Bowling Green
# Error in parse_linescore: division by zero
# Processing box score for 2020-11-14-Arizona State-Michigan
# Processing box score for 2020-11-14-Wisconsin-Notre Dame
# Processing box score for 2020-11-15-Arizona State-Michigan
# Processing box score for 2020-11-19-Long Island-Holy Cross
# Processing box score for 2020-11-19-Arizona State-Michigan State
# Processing box score for 2020-11-19-Michigan-Wisconsin
# Processing box score for 2020-11-19-Penn State-Minnesota
# Processing box score for 2020-11-20-Penn State-Minnesota
# Processing box score for 2020-11-20-Michigan-Wisconsin
# Processing box score for 2020-11-20-Connecticut-Massachusetts
# Processing box score for 2020-11-20-Arizona State-Michigan State
# Processing box score for 2020-11-21-Massachusetts-Connecticut
# Processing box score for 2020-11-21-Michigan Tech-Lake Superior
# Processing box score for 2020-11-21-Alabama Huntsville-Robert Morris
# Processing box score for 2020-11-21-Bowling Green-Adrian
# Error in parse_linescore: division by zero
# Processing box score for 2020-11-22-Michigan Tech-Lake Superior
# Processing box score for 2020-11-22-Long Island-Holy Cross
# Processing box score for 2020-11-22-Clarkson-Colgate
# Processing box score for 2020-11-22-Alabama Huntsville-Robert Morris
# Processing box score for 2020-11-22-Minnesota State-Bemidji State
# Processing box score for 2020-11-23-Penn State-Wisconsin
# Processing box score for 2020-11-23-Ohio State-Minnesota
# Processing box score for 2020-11-24-Penn State-Wisconsin
# Processing box score for 2020-11-24-Ohio State-Minnesota
# Processing box score for 2020-11-27-Air Force-American Int'l
# Processing box score for 2020-11-27-Canisius-Robert Morris
# Processing box score for 2020-11-27-Clarkson-RIT
# Processing box score for 2020-11-27-Massachusetts-Boston College
# Processing box score for 2020-11-27-Notre Dame-Michigan
# Processing box score for 2020-11-27-Adrian-Lake Superior
# Error in parse_linescore: division by zero
# Processing box score for 2020-11-28-Air Force-American Int'l
# Processing box score for 2020-11-28-Canisius-Robert Morris
# Processing box score for 2020-11-28-Boston College-Massachusetts
# Processing box score for 2020-11-28-Michigan State-Ohio State
# Processing box score for 2020-11-28-Notre Dame-Michigan
# Processing box score for 2020-11-28-Arizona State-Wisconsin
# Processing box score for 2020-11-29-Lake Superior-Adrian
# Error in parse_linescore: division by zero
# Processing box score for 2020-11-29-Arizona State-Wisconsin
# Processing box score for 2020-11-29-RIT-Clarkson
# Processing box score for 2020-11-29-Michigan State-Ohio State
# Processing box score for 2020-12-01-Minnesota Duluth-Nebraska Omaha
# Processing box score for 2020-12-01-St. Cloud State-Western Michigan
# Processing box score for 2020-12-01-Holy Cross-Bentley
# Processing box score for 2020-12-01-Bowling Green-Robert Morris
# Processing box score for 2020-12-02-Miami-North Dakota
# Processing box score for 2020-12-02-Denver-Minnesota Duluth
# Processing box score for 2020-12-02-Michigan-Penn State
# Processing box score for 2020-12-03-Wisconsin-Ohio State
# Processing box score for 2020-12-03-Michigan-Penn State
# Processing box score for 2020-12-03-Minnesota-Michigan State
# Processing box score for 2020-12-03-Arizona State-Notre Dame
# Processing box score for 2020-12-03-Nebraska Omaha-Western Michigan
# Processing box score for 2020-12-04-Army-Bentley
# Processing box score for 2020-12-04-Sacred Heart-Holy Cross
# Processing box score for 2020-12-04-Robert Morris-Air Force
# Processing box score for 2020-12-04-Wisconsin-Ohio State
# Processing box score for 2020-12-04-Minnesota-Michigan State
# Processing box score for 2020-12-04-Providence-Boston College
# Processing box score for 2020-12-04-Arizona State-Notre Dame
# Processing box score for 2020-12-04-North Dakota-Denver
# Processing box score for 2020-12-05-Mercyhurst-Bowling Green
# Processing box score for 2020-12-05-Alabama Huntsville-Lake Superior
# Processing box score for 2020-12-05-Merrimack-Massachusetts
# Processing box score for 2020-12-05-Boston College-Providence
# Processing box score for 2020-12-05-Niagara-RIT
# Processing box score for 2020-12-05-Robert Morris-Air Force
# Processing box score for 2020-12-05-Bentley-Army
# Processing box score for 2020-12-05-Miami-Nebraska Omaha
# Processing box score for 2020-12-05-St. Cloud State-Denver
# Processing box score for 2020-12-06-North Dakota-Western Michigan
# Processing box score for 2020-12-06-Minnesota Duluth-Miami
# Processing box score for 2020-12-06-Nebraska Omaha-St. Cloud State
# Processing box score for 2020-12-06-Sacred Heart-Holy Cross
# Processing box score for 2020-12-06-RIT-Niagara
# Processing box score for 2020-12-06-Bowling Green-Mercyhurst
# Processing box score for 2020-12-06-Alabama Huntsville-Lake Superior
# Processing box score for 2020-12-06-Minnesota State-Michigan Tech
# Processing box score for 2020-12-06-Massachusetts-Merrimack
# Processing box score for 2020-12-07-Minnesota State-Michigan Tech
# Processing box score for 2020-12-08-Western Michigan-Colorado College
# Processing box score for 2020-12-08-Denver-North Dakota
# Processing box score for 2020-12-08-Miami-Minnesota Duluth
# Processing box score for 2020-12-08-Minnesota-Michigan
# Processing box score for 2020-12-09-Western Michigan-St. Cloud State
# Processing box score for 2020-12-09-Nebraska Omaha-Colorado College
# Processing box score for 2020-12-09-Clarkson-Niagara
# Processing box score for 2020-12-09-Bentley-Holy Cross
# Processing box score for 2020-12-09-Minnesota-Michigan
# Processing box score for 2020-12-10-Denver-Miami
# Processing box score for 2020-12-10-North Dakota-Minnesota Duluth
# Processing box score for 2020-12-11-Long Island-RIT
# Processing box score for 2020-12-11-Arizona State-Penn State
# Processing box score for 2020-12-11-Ferris State-Bowling Green
# Processing box score for 2020-12-11-Connecticut-Boston College
# Processing box score for 2020-12-11-Maine-New Hampshire
# Processing box score for 2020-12-11-Colorado College-Western Michigan
# Processing box score for 2020-12-12-Minnesota Duluth-Denver
# Processing box score for 2020-12-12-St. Cloud State-North Dakota
# Processing box score for 2020-12-12-Nebraska Omaha-Miami
# Processing box score for 2020-12-12-Boston College-Connecticut
# Processing box score for 2020-12-12-Merrimack-Northeastern
# Processing box score for 2020-12-12-Maine-New Hampshire
# Processing box score for 2020-12-12-Long Island-RIT
# Processing box score for 2020-12-12-Clarkson-Mercyhurst
# Processing box score for 2020-12-12-Michigan Tech-Bemidji State
# Processing box score for 2020-12-12-Bowling Green-Ferris State
# Processing box score for 2020-12-12-Ohio State-Notre Dame
# Processing box score for 2020-12-13-Minnesota Duluth-Colorado College
# Processing box score for 2020-12-13-Western Michigan-North Dakota
# Processing box score for 2020-12-13-St. Cloud State-Nebraska Omaha
# Processing box score for 2020-12-13-Arizona State-Penn State
# Processing box score for 2020-12-13-Michigan Tech-Bemidji State
# Processing box score for 2020-12-13-Clarkson-Mercyhurst
# Processing box score for 2020-12-13-Northeastern-Merrimack
# Processing box score for 2020-12-13-Providence-Mass. Lowell
# Processing box score for 2020-12-13-Ohio State-Notre Dame
# Processing box score for 2020-12-14-Sacred Heart-Quinnipiac
# Processing box score for 2020-12-15-Denver-Western Michigan
# Processing box score for 2020-12-15-Miami-Colorado College
# Processing box score for 2020-12-15-Army-American Int'l
# Processing box score for 2020-12-15-Sacred Heart-Quinnipiac
# Processing box score for 2020-12-16-Nebraska Omaha-Minnesota Duluth
# Processing box score for 2020-12-16-North Dakota-St. Cloud State
# Processing box score for 2020-12-16-Niagara-Mercyhurst
# Processing box score for 2020-12-16-Ferris State-Northern Michigan
# Processing box score for 2020-12-17-Arizona State-Ohio State
# Processing box score for 2020-12-17-Miami-Denver
# Processing box score for 2020-12-18-Western Michigan-Nebraska Omaha
# Processing box score for 2020-12-18-St. Cloud State-Colorado College
# Processing box score for 2020-12-18-American Int'l-Bentley
# Processing box score for 2020-12-18-Mercyhurst-Niagara
# Processing box score for 2020-12-18-Arizona State-Ohio State
# Processing box score for 2020-12-18-Bowling Green-Quinnipiac
# Processing box score for 2020-12-18-Northern Michigan-Michigan Tech
# Processing box score for 2020-12-18-Bemidji State-Minnesota State
# Processing box score for 2020-12-19-Providence-Northeastern
# Processing box score for 2020-12-19-Vermont-Massachusetts
# Processing box score for 2020-12-19-Bentley-American Int'l
# Processing box score for 2020-12-19-Minnesota Duluth-North Dakota
# Processing box score for 2020-12-19-Western Michigan-Denver
# Processing box score for 2020-12-19-Colorado College-Miami
# Processing box score for 2020-12-19-Bemidji State-Minnesota State
# Processing box score for 2020-12-19-Michigan Tech-Northern Michigan
# Processing box score for 2020-12-19-Bowling Green-Quinnipiac
# Processing box score for 2020-12-19-Michigan State-Notre Dame
# Processing box score for 2020-12-20-Northeastern-Providence
# Processing box score for 2020-12-20-Vermont-Massachusetts
# Processing box score for 2020-12-20-Michigan State-Notre Dame
# Processing box score for 2020-12-20-Denver-St. Cloud State
# Processing box score for 2020-12-20-North Dakota-Miami
# Processing box score for 2020-12-21-Colorado College-Nebraska Omaha
# Processing box score for 2020-12-21-Mass. Lowell-Connecticut
# Processing box score for 2020-12-22-RIT-Niagara
# Processing box score for 2020-12-22-Holy Cross-Quinnipiac
# Processing box score for 2020-12-23-Connecticut-Massachusetts
# Processing box score for 2020-12-23-Colgate-Clarkson
# Processing box score for 2020-12-23-Quinnipiac-Holy Cross
# Processing box score for 2020-12-26-Northeastern-Vermont
# Processing box score for 2020-12-26-American Int'l-Quinnipiac
# Processing box score for 2020-12-27-Quinnipiac-American Int'l
# Processing box score for 2020-12-27-Northeastern-Vermont
# Processing box score for 2020-12-28-Providence-Connecticut
# Processing box score for 2020-12-29-Robert Morris-Bowling Green
# Processing box score for 2020-12-29-RIT-Colgate
# Processing box score for 2020-12-29-Niagara-Clarkson
# Processing box score for 2020-12-30-Northern Michigan-Ferris State
# Processing box score for 2020-12-30-Massachusetts-New Hampshire
# Processing box score for 2020-12-31-Robert Morris-Niagara
# Processing box score for 2020-12-31-Quinnipiac-St. Lawrence
# Processing box score for 2021-01-01-Vermont-Providence
# Processing box score for 2021-01-01-Connecticut-New Hampshire
# Processing box score for 2021-01-01-Massachusetts-Northeastern
# Processing box score for 2021-01-01-Clarkson-Colgate
# Processing box score for 2021-01-01-Denver-Colorado College
# Processing box score for 2021-01-02-Mercyhurst-Canisius
# Processing box score for 2021-01-02-RIT-Robert Morris
# Processing box score for 2021-01-02-Long Island-American Int'l
# Processing box score for 2021-01-02-Bemidji State-Lake Superior
# Processing box score for 2021-01-02-Bowling Green-Ferris State
# Processing box score for 2021-01-02-Alabama Huntsville-Michigan Tech
# Processing box score for 2021-01-02-Minnesota State-Northern Michigan
# Processing box score for 2021-01-02-New Hampshire-Connecticut
# Processing box score for 2021-01-02-Northeastern-Massachusetts
# Processing box score for 2021-01-02-Vermont-Providence
# Processing box score for 2021-01-02-Miami-Western Michigan
# Processing box score for 2021-01-02-Minnesota Duluth-St. Cloud State
# Processing box score for 2021-01-02-Colorado College-Denver
# Processing box score for 2021-01-03-St. Lawrence-Quinnipiac
# Processing box score for 2021-01-03-Colgate-Clarkson
# Processing box score for 2021-01-03-Alabama Huntsville-Michigan Tech
# Processing box score for 2021-01-03-Bowling Green-Ferris State
# Processing box score for 2021-01-03-Minnesota State-Northern Michigan
# Processing box score for 2021-01-03-Penn State-Michigan State
# Processing box score for 2021-01-03-Canisius-Mercyhurst
# Processing box score for 2021-01-03-RIT-Robert Morris
# Processing box score for 2021-01-03-Air Force-Niagara
# Processing box score for 2021-01-03-Bemidji State-Lake Superior
# Processing box score for 2021-01-03-Arizona State-Minnesota
# Processing box score for 2021-01-03-Minnesota Duluth-St. Cloud State
# Processing box score for 2021-01-03-Miami-Western Michigan
# Processing box score for 2021-01-03-Maine-Mass. Lowell
# Processing box score for 2021-01-04-Maine-Mass. Lowell
# Processing box score for 2021-01-04-Penn State-Michigan State
# Processing box score for 2021-01-04-Air Force-Niagara
# Processing box score for 2021-01-04-Arizona State-Minnesota
# Processing box score for 2021-01-06-Sacred Heart-Air Force
# Processing box score for 2021-01-06-American Int'l-Army
# Processing box score for 2021-01-06-New Hampshire-Massachusetts
# Processing box score for 2021-01-07-St. Lawrence-Colgate
# Processing box score for 2021-01-07-American Int'l-Army
# Processing box score for 2021-01-07-Robert Morris-Niagara
# Processing box score for 2021-01-07-Bemidji State-Bowling Green
# Processing box score for 2021-01-08-Maine-Vermont
# Processing box score for 2021-01-08-Providence-Boston University
# Processing box score for 2021-01-08-New Hampshire-Boston College
# Processing box score for 2021-01-08-Air Force-Mercyhurst
# Processing box score for 2021-01-08-Penn State-Ohio State
# Processing box score for 2021-01-08-Michigan State-Michigan
# Processing box score for 2021-01-08-Clarkson-Quinnipiac
# Processing box score for 2021-01-08-Western Michigan-Miami
# Processing box score for 2021-01-08-St. Cloud State-Minnesota Duluth
# Processing box score for 2021-01-08-Bemidji State-Bowling Green
# Processing box score for 2021-01-08-Ferris State-Alabama Huntsville
# Processing box score for 2021-01-08-Lake Superior-Northern Michigan
# Processing box score for 2021-01-09-Maine-Vermont
# Processing box score for 2021-01-09-Merrimack-Northeastern
# Processing box score for 2021-01-09-Boston University-Providence
# Processing box score for 2021-01-09-Air Force-Mercyhurst
# Processing box score for 2021-01-09-Niagara-Robert Morris
# Processing box score for 2021-01-09-Michigan-Michigan State
# Processing box score for 2021-01-09-Minnesota-Wisconsin
# Processing box score for 2021-01-09-Penn State-Ohio State
# Processing box score for 2021-01-09-Western Michigan-Miami
# Processing box score for 2021-01-09-St. Cloud State-Minnesota Duluth
# Processing box score for 2021-01-09-Lake Superior-Northern Michigan
# Processing box score for 2021-01-09-Arizona State-Notre Dame
# Processing box score for 2021-01-09-Clarkson-Quinnipiac
# Processing box score for 2021-01-09-Colgate-St. Lawrence
# Processing box score for 2021-01-09-Ferris State-Alabama Huntsville
# Processing box score for 2021-01-10-Northeastern-Merrimack
# Processing box score for 2021-01-10-Boston College-New Hampshire
# Processing box score for 2021-01-10-Clarkson-Quinnipiac
# Processing box score for 2021-01-10-Colgate-St. Lawrence
# Processing box score for 2021-01-10-Niagara-Robert Morris
# Processing box score for 2021-01-10-Army-American Int'l
# Processing box score for 2021-01-10-Minnesota-Wisconsin
# Processing box score for 2021-01-10-Arizona State-Notre Dame
# Processing box score for 2021-01-10-North Dakota-Colorado College
# Processing box score for 2021-01-11-North Dakota-Colorado College
# Processing box score for 2021-01-13-Long Island-American Int'l
# Processing box score for 2021-01-13-New Hampshire-Northeastern
# Processing box score for 2021-01-15-Maine-Providence
# Processing box score for 2021-01-15-New Hampshire-Connecticut
# Processing box score for 2021-01-15-Quinnipiac-Colgate
# Processing box score for 2021-01-15-St. Lawrence-Clarkson
# Processing box score for 2021-01-15-Long Island-Army
# Processing box score for 2021-01-15-Northern Michigan-Bowling Green
# Processing box score for 2021-01-15-Michigan State-Penn State
# Processing box score for 2021-01-15-Ohio State-Michigan
# Processing box score for 2021-01-15-Notre Dame-Minnesota
# Processing box score for 2021-01-15-St. Cloud State-Western Michigan
# Processing box score for 2021-01-15-Minnesota State-Lake Superior
# Processing box score for 2021-01-16-Trine-Ferris State
# Processing box score for 2021-01-16-Michigan State-Penn State
# Processing box score for 2021-01-16-Notre Dame-Minnesota
# Processing box score for 2021-01-16-Ohio State-Michigan
# Processing box score for 2021-01-16-Maine-Providence
# Processing box score for 2021-01-16-Connecticut-New Hampshire
# Processing box score for 2021-01-16-Merrimack-Boston College
# Processing box score for 2021-01-16-Minnesota State-Lake Superior
# Processing box score for 2021-01-16-Long Island-Army
# Processing box score for 2021-01-16-Northern Michigan-Bowling Green
# Processing box score for 2021-01-16-Arizona State-Wisconsin
# Processing box score for 2021-01-16-St. Cloud State-Western Michigan
# Processing box score for 2021-01-17-Holy Cross-American Int'l
# Processing box score for 2021-01-17-Boston University-Massachusetts
# Processing box score for 2021-01-17-Boston College-Merrimack
# Processing box score for 2021-01-17-Clarkson-St. Lawrence
# Processing box score for 2021-01-17-Colgate-Quinnipiac
# Processing box score for 2021-01-17-Arizona State-Wisconsin
# Processing box score for 2021-01-17-North Dakota-Denver
# Processing box score for 2021-01-18-Massachusetts-Boston University
# Processing box score for 2021-01-18-Nebraska Omaha-Colorado College
# Processing box score for 2021-01-18-North Dakota-Denver
# Processing box score for 2021-01-19-Robert Morris-Mercyhurst
# Processing box score for 2021-01-19-Nebraska Omaha-Colorado College
# Processing box score for 2021-01-21-Colgate-St. Lawrence
# Processing box score for 2021-01-21-Wisconsin-Penn State
# Processing box score for 2021-01-21-Michigan-Notre Dame
# Processing box score for 2021-01-21-Army-Holy Cross
# Processing box score for 2021-01-21-Bowling Green-Bemidji State
# Processing box score for 2021-01-21-Arizona State-Minnesota
# Processing box score for 2021-01-22-Providence-Massachusetts
# Processing box score for 2021-01-22-Maine-Boston University
# Processing box score for 2021-01-22-Connecticut-Boston College
# Processing box score for 2021-01-22-Merrimack-New Hampshire
# Processing box score for 2021-01-22-Bowling Green-Bemidji State
# Processing box score for 2021-01-22-Arizona State-Minnesota
# Processing box score for 2021-01-22-Quinnipiac-Clarkson
# Processing box score for 2021-01-22-Wisconsin-Penn State
# Processing box score for 2021-01-22-Michigan-Notre Dame
# Processing box score for 2021-01-22-Army-Holy Cross
# Processing box score for 2021-01-22-Miami-St. Cloud State
# Processing box score for 2021-01-23-Maine-Boston University
# Processing box score for 2021-01-23-New Hampshire-Merrimack
# Processing box score for 2021-01-23-Boston College-Connecticut
# Processing box score for 2021-01-23-Massachusetts-Providence
# Processing box score for 2021-01-23-Quinnipiac-Clarkson
# Processing box score for 2021-01-23-St. Lawrence-Colgate
# Processing box score for 2021-01-23-Ohio State-Michigan State
# Processing box score for 2021-01-23-Northern Michigan-Michigan Tech
# Processing box score for 2021-01-23-Robert Morris-Mercyhurst
# Processing box score for 2021-01-23-Ferris State-Minnesota State
# Processing box score for 2021-01-23-Denver-Nebraska Omaha
# Processing box score for 2021-01-23-Colorado College-North Dakota
# Processing box score for 2021-01-23-Western Michigan-Minnesota Duluth
# Processing box score for 2021-01-23-Miami-St. Cloud State
# Processing box score for 2021-01-24-St. Lawrence-Colgate
# Processing box score for 2021-01-24-Quinnipiac-Clarkson
# Processing box score for 2021-01-24-Ohio State-Michigan State
# Processing box score for 2021-01-24-Ferris State-Minnesota State
# Processing box score for 2021-01-24-Western Michigan-Minnesota Duluth
# Processing box score for 2021-01-24-Denver-Nebraska Omaha
# Processing box score for 2021-01-24-Colorado College-North Dakota
# Processing box score for 2021-01-25-Michigan Tech-Northern Michigan
# Processing box score for 2021-01-26-Sacred Heart-American Int'l
# Processing box score for 2021-01-26-Holy Cross-Bentley
# Processing box score for 2021-01-28-Mercyhurst-RIT
# Processing box score for 2021-01-28-Notre Dame-Penn State
# Processing box score for 2021-01-29-Connecticut-Merrimack
# Processing box score for 2021-01-29-Providence-New Hampshire
# Processing box score for 2021-01-29-Mass. Lowell-Massachusetts
# Processing box score for 2021-01-29-American Int'l-Holy Cross
# Processing box score for 2021-01-29-Sacred Heart-Army
# Processing box score for 2021-01-29-Minnesota State-Bemidji State
# Processing box score for 2021-01-29-Minnesota-Ohio State
# Processing box score for 2021-01-29-Notre Dame-Penn State
# Processing box score for 2021-01-29-Michigan State-Wisconsin
# Processing box score for 2021-01-29-Minnesota Duluth-Miami
# Processing box score for 2021-01-29-North Dakota-Nebraska Omaha
# Processing box score for 2021-01-29-Michigan Tech-Bowling Green
# Processing box score for 2021-01-29-Ferris State-Northern Michigan
# Processing box score for 2021-01-30-Holy Cross-American Int'l
# Processing box score for 2021-01-30-Canisius-RIT
# Processing box score for 2021-01-30-Army-Sacred Heart
# Processing box score for 2021-01-30-Mercyhurst-Robert Morris
# Processing box score for 2021-01-30-Merrimack-Connecticut
# Processing box score for 2021-01-30-Massachusetts-Mass. Lowell
# Processing box score for 2021-01-30-Michigan State-Wisconsin
# Processing box score for 2021-01-30-Minnesota-Ohio State
# Processing box score for 2021-01-30-Minnesota Duluth-Miami
# Processing box score for 2021-01-30-North Dakota-Nebraska Omaha
# Processing box score for 2021-01-30-Ferris State-Northern Michigan
# Processing box score for 2021-01-30-Michigan Tech-Bowling Green
# Processing box score for 2021-01-31-New Hampshire-Providence
# Processing box score for 2021-01-31-Air Force-Bentley
# Processing box score for 2021-02-01-Air Force-Bentley
# Processing box score for 2021-02-02-Boston College-Northeastern
# Processing box score for 2021-02-02-Michigan Tech-Ferris State
# Processing box score for 2021-02-04-Colgate-Clarkson
# Processing box score for 2021-02-04-Sacred Heart-Bentley
# Processing box score for 2021-02-04-Long Island-Robert Morris
# Processing box score for 2021-02-05-Long Island-Robert Morris
# Processing box score for 2021-02-05-Michigan Tech-Alabama Huntsville
# Processing box score for 2021-02-05-St. Lawrence-Quinnipiac
# Processing box score for 2021-02-05-Notre Dame-Ohio State
# Processing box score for 2021-02-05-Wisconsin-Minnesota
# Processing box score for 2021-02-05-Connecticut-Northeastern
# Processing box score for 2021-02-05-New Hampshire-Mass. Lowell
# Processing box score for 2021-02-05-Boston University-Boston College
# Processing box score for 2021-02-05-Bentley-Sacred Heart
# Processing box score for 2021-02-05-Mercyhurst-RIT
# Processing box score for 2021-02-05-Bemidji State-Ferris State
# Processing box score for 2021-02-05-Bowling Green-Minnesota State
# Processing box score for 2021-02-05-Miami-Minnesota Duluth
# Processing box score for 2021-02-05-Western Michigan-St. Cloud State

# %%
# backup_all_dfs = all_dfs.copy()

# %%
all_dfs = [df for df in all_dfs if isinstance(df, pd.DataFrame)]

combined_df = pd.concat(all_dfs, axis=0)

# %%
combined_df.info()

# Save to a CSV file
# combined_df.to_csv(f'../TEMP/{tag}_combined.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 0 to 1
# Data columns (total 52 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Day           1 non-null      object
#  1   Date          1 non-null      object
#  2   Conference    1 non-null      object
#  3   Details       0 non-null      object
#  4   Location      1 non-null      object
#  5   Ref1          1 non-null      object
#  6   Ref2          0 non-null      object
#  7   Asst_Ref1     1 non-null      object
#  8   Asst_Ref2     0 non-null      object
#  9   Attendance    0 non-null      object
#  10  Game_ID       83 non-null     object
#  11  Period        31 non-null     object
#  12  Team          82 non-null     object
#  13  PP            14 non-null     object
#  14  Player        74 non-null     object
#  15  Player_Goals  14 non-null     float64
#  16  Assist1       14 non-null     object
#  17  Assist2       13 non-null     object
#  18  Time          31 non-null     object
#  19  Pen_Length    17 non-null     object
#  20  Penalty_Type  17 non-null     object
#  21  Goalie        6 non-null      object
#  22  SV            6 non-null      object
#  23  GA            6 non-null      object
#  24  Minutes       6 non-null      object
#  25  G             43 non-null     object
#  26  A             43 non-null     object
#  27  Pt.           43 non-null     object
#  28  +/-           43 non-null     object
#  29  Sh            43 non-null     object
#  30  PIM           45 non-null     object
#  31  FOW           15 non-null     float64
#  32  FOL           15 non-null     float64
#  33  FO%           13 non-null     float64
#  34  goals1        2 non-null      float64
#  35  goals2        2 non-null      float64
#  36  goals3        2 non-null      float64
#  37  goalsT        2 non-null      float64
#  38  shots1        2 non-null      float64
#  39  shots2        2 non-null      float64
#  40  shots3        2 non-null      float64
#  41  shotsT        2 non-null      float64
#  42  Pen           2 non-null      float64
#  43  PPG           2 non-null      float64
#  44  PPO           2 non-null      float64
#  45  FOW%          2 non-null      float64
#  46  goals4        2 non-null      float64
#  47  goals5        2 non-null      float64
#  48  goals6        2 non-null      float64
#  49  shots4        2 non-null      float64
#  50  shots5        2 non-null      float64
#  51  shots6        2 non-null      float64
# dtypes: float64(22), object(30)
# memory usage: 34.4+ KB
